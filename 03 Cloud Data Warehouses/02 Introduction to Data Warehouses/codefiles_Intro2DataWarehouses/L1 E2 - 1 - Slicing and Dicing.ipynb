# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Slicing and Dicing

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://video.udacity-data.com/topher/2021/August/61120e06_pagila-3nf/pagila-3nf.png)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](https://video.udacity-data.com/topher/2021/August/61120d38_pagila-star/pagila-star.png)
#
# Start by creating and connecting to the database by running the cells below.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql
# Out:
#  set_config
# ------------
#
# (1 row)
#
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Start with a simple cube
# TODO: Write a query that calculates the revenue (sales_amount) by day, rating, and city. Remember to join with the appropriate dimension tables to replace the keys with the dimension labels. Sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT
    dt.day,
    dm.rating,
    dc.city,
    sum(sales_amount) as revenue
FROM factsales fs
JOIN dimDate dt ON (fs.date_key = dt.date_key)
JOIN dimMovie dm ON (fs.movie_key = dm.movie_key)
JOIN dimCustomer dc on (fs.customer_key = dc.customer_key)
GROUP BY dt.day, dm.rating, dc.city
ORDER BY 4 DESC
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 14167 rows affected.
# CPU times: user 26.6 ms, sys: 2.85 ms, total: 29.5 ms
# Wall time: 57.1 ms
# [(30, 'G', 'San Bernardino', Decimal('24.97')),
#  (30, 'NC-17', 'Apeldoorn', Decimal('23.95')),
#  (21, 'NC-17', 'Belm', Decimal('22.97')),
#  (21, 'G', 'Citt del Vaticano', Decimal('21.97')),
#  (28, 'R', 'Mwanza', Decimal('21.97')),
#  (30, 'PG-13', 'Zanzibar', Decimal('21.97')),
#  (22, 'R', 'Yangor', Decimal('19.97')),
#  (28, 'PG-13', 'Dhaka', Decimal('19.97')),
#  (17, 'G', 'Rajkot', Decimal('19.97')),
#  (1, 'R', 'Qomsheh', Decimal('19.97')),
#  (19, 'PG', 'Najafabad', Decimal('19.96')),
#  (30, 'R', 'Fengshan', Decimal('19.95')),
#  (21, 'G', 'Wroclaw', Decimal('18.98')),
#  (28, 'PG', 'So Leopoldo', Decimal('18.98')),
#  (29, 'PG-13', 'Shimoga', Decimal('18.97')),
#  (30, 'PG-13', 'Osmaniye', Decimal('18.97')),
#  (1, 'NC-17', 'Memphis', Decimal('18.97')),
#  (30, 'G', 'Omdurman', Decimal('18.97')),
#  (19, 'PG', 'Sokoto', Decimal('18.97')),
#  (21, 'PG-13', 'Asuncin', Decimal('18.95')),
#  (30, 'PG-13', 'Nagareyama', Decimal('17.98')),
#  (21, 'PG-13', 'Parbhani', Decimal('17.98')),
#  (19, 'PG', 'Loja', Decimal('17.98')),
#  (20, 'PG-13', 'Baha Blanca', Decimal('17.98')),
#  (2, 'NC-17', 'Valparai', Decimal('17.98')),
#  (18, 'R', 'Sumy', Decimal('17.98')),
#  (19, 'G', 'Ozamis', Decimal('17.98')),
#  (12, 'NC-17', 'Plock', Decimal('17.98')),
#  (23, 'NC-17', 'Adana', Decimal('17.98')),
#  (30, 'G', 'Tychy', Decimal('17.98')),
#  (17, 'R', 'Birgunj', Decimal('17.97')),
#  (30, 'R', 'Robamba', Decimal('17.97')),
#  (19, 'R', 'Kowloon and New Kowloon', Decimal('17.97')),
#  (19, 'NC-17', 'Lengshuijiang', Decimal('17.97')),
#  (30, 'PG-13', 'Tanauan', Decimal('17.96')),
#  (17, 'PG-13', 'Ikerre', Decimal('17.95')),
#  (10, 'NC-17', 'Vijayawada', Decimal('16.98')),
#  (2, 'NC-17', 'Kuwana', Decimal('16.98')),
#  (1, 'NC-17', 'Gatineau', Decimal('16.98')),
#  (21, 'PG', 'Zhoushan', Decimal('16.98')),
#  (11, 'R', 'Gandhinagar', Decimal('16.98')),
#  (10, 'G', 'Omdurman', Decimal('16.98')),
#  (30, 'PG-13', 'Zhoushan', Decimal('16.98')),
#  (17, 'R', 'NDjamna', Decimal('16.98')),
#  (9, 'G', 'Fontana', Decimal('16.97')),
#  (28, 'R', 'Usolje-Sibirskoje', Decimal('16.97')),
#  (30, 'R', 'San Lorenzo', Decimal('16.97')),
#  (18, 'NC-17', 'Salzburg', Decimal('16.97')),
#  (19, 'NC-17', 'Tangail', Decimal('16.97')),
#  (30, 'PG-13', 'Newcastle', Decimal('16.97')),
#  (29, 'R', 'Baiyin', Decimal('16.97')),
#  (30, 'PG-13', 'Yerevan', Decimal('16.97')),
#  (29, 'R', 'Atlixco', Decimal('15.98')),
#  (20, 'G', 'Liaocheng', Decimal('15.98')),
#  (30, 'G', 'Yinchuan', Decimal('15.98')),
#  (17, 'PG-13', 'Yantai', Decimal('15.98')),
#  (1, 'PG', 'El Monte', Decimal('15.98')),
#  (18, 'R', 'Juazeiro do Norte', Decimal('15.98')),
#  (19, 'PG', 'Akron', Decimal('15.98')),
#  (18, 'NC-17', 'Ahmadnagar', Decimal('15.98')),
#  (28, 'PG', 'Naala-Porto', Decimal('15.98')),
#  (30, 'NC-17', 'Vancouver', Decimal('15.98')),
#  (30, 'PG-13', 'Santa Rosa', Decimal('15.98')),
#  (20, 'PG-13', 'Santa Rosa', Decimal('15.98')),
#  (28, 'NC-17', 'Mexicali', Decimal('15.98')),
#  (30, 'PG', 'Purnea (Purnia)', Decimal('15.98')),
#  (16, 'R', 'Athenai', Decimal('15.98')),
#  (30, 'NC-17', 'Quilmes', Decimal('15.98')),
#  (1, 'G', 'Songkhla', Decimal('15.98')),
#  (6, 'NC-17', 'Phnom Penh', Decimal('15.98')),
#  (8, 'PG-13', 'Pontianak', Decimal('15.98')),
#  (30, 'R', 'So Bernardo do Campo', Decimal('15.98')),
#  (8, 'PG', 'Benin City', Decimal('15.98')),
#  (20, 'R', 'Cuman', Decimal('15.98')),
#  (27, 'G', 'Salala', Decimal('15.98')),
#  (17, 'G', 'Ondo', Decimal('15.98')),
#  (29, 'PG', 'Huejutla de Reyes', Decimal('15.97')),
#  (1, 'PG-13', 'Moscow', Decimal('15.97')),
#  (10, 'PG-13', 'Udaipur', Decimal('15.97')),
#  (30, 'PG-13', 'Toulouse', Decimal('15.97')),
#  (30, 'NC-17', 'Nakhon Sawan', Decimal('15.97')),
#  (30, 'G', 'Hohhot', Decimal('15.97')),
#  (17, 'PG', 'Kakamigahara', Decimal('15.97')),
#  (18, 'PG', 'Kamarhati', Decimal('15.97')),
#  (23, 'PG-13', 'Tiefa', Decimal('15.97')),
#  (17, 'NC-17', 'Lancaster', Decimal('15.97')),
#  (17, 'G', 'Usak', Decimal('15.97')),
#  (20, 'PG-13', 'Johannesburg', Decimal('15.97')),
#  (21, 'R', 'Nam Dinh', Decimal('15.96')),
#  (19, 'PG-13', 'Touliu', Decimal('14.98')),
#  (18, 'PG-13', 'Okayama', Decimal('14.98')),
#  (28, 'G', 'Tanshui', Decimal('14.98')),
#  (29, 'G', 'Vila Velha', Decimal('14.98')),
#  (22, 'G', 'Erlangen', Decimal('14.98')),
#  (8, 'NC-17', 'Vila Velha', Decimal('14.98')),
#  (30, 'R', 'Changhwa', Decimal('14.98')),
#  (8, 'PG', 'Bellevue', Decimal('14.98')),
#  (29, 'NC-17', 'Osmaniye', Decimal('14.98')),
#  (28, 'R', 'Papeete', Decimal('14.98')),
#  (18, 'G', 'Omiya', Decimal('14.98')),
#  (27, 'PG-13', 'Sawhaj', Decimal('14.98')),
#  (10, 'G', 'Goinia', Decimal('14.98')),
#  (1, 'PG', 'Rajkot', Decimal('14.98')),
#  (12, 'PG', 'Portoviejo', Decimal('14.98')),
#  (29, 'PG-13', 'Gaziantep', Decimal('14.98')),
#  (16, 'PG', 'Skikda', Decimal('14.98')),
#  (27, 'PG-13', 'Gulbarga', Decimal('14.98')),
#  (6, 'NC-17', 'Konotop', Decimal('14.98')),
#  (30, 'PG', 'Akron', Decimal('14.98')),
#  (19, 'PG-13', 'Owo', Decimal('14.98')),
#  (27, 'NC-17', 'Tianjin', Decimal('14.98')),
#  (8, 'NC-17', 'Quilmes', Decimal('14.98')),
#  (30, 'NC-17', 'Halisahar', Decimal('14.98')),
#  (12, 'PG-13', 'Usolje-Sibirskoje', Decimal('14.98')),
#  (21, 'PG-13', 'Aden', Decimal('14.98')),
#  (19, 'G', 'Allende', Decimal('14.98')),
#  (28, 'R', 'Otsu', Decimal('14.98')),
#  (30, 'G', 'Serpuhov', Decimal('14.98')),
#  (20, 'G', 'Aurora', Decimal('14.97')),
#  (7, 'PG', 'Citt del Vaticano', Decimal('14.97')),
#  (30, 'NC-17', 'Mukateve', Decimal('14.97')),
#  (20, 'PG-13', 'Ciparay', Decimal('14.97')),
#  (1, 'PG', 'Santiago de los Caballeros', Decimal('14.97')),
#  (18, 'PG-13', 'Shimonoseki', Decimal('14.97')),
#  (21, 'PG', 'Tanza', Decimal('14.97')),
#  (21, 'NC-17', 'Kolpino', Decimal('14.97')),
#  (30, 'NC-17', 'Warren', Decimal('14.97')),
#  (27, 'PG-13', 'Phnom Penh', Decimal('14.97')),
#  (18, 'NC-17', 'Coquimbo', Decimal('14.97')),
#  (19, 'NC-17', 'London', Decimal('14.97')),
#  (30, 'R', 'Satna', Decimal('14.97')),
#  (18, 'PG-13', 'Cavite', Decimal('14.97')),
#  (29, 'PG-13', 'Cuauhtmoc', Decimal('13.98')),
#  (30, 'R', 'Maracabo', Decimal('13.98')),
#  (2, 'NC-17', 'Cayenne', Decimal('13.98')),
#  (11, 'PG', 'Laredo', Decimal('13.98')),
#  (30, 'G', 'Davao', Decimal('13.98')),
#  (8, 'NC-17', 'Omiya', Decimal('13.98')),
#  (26, 'G', 'Ashgabat', Decimal('13.98')),
#  (22, 'PG', 'Saint-Denis', Decimal('13.98')),
#  (30, 'R', 'Yinchuan', Decimal('13.98')),
#  (16, 'G', 'Chungho', Decimal('13.98')),
#  (15, 'PG-13', 'Valparai', Decimal('13.98')),
#  (29, 'G', 'Bucuresti', Decimal('13.98')),
#  (17, 'G', 'Hubli-Dharwad', Decimal('13.98')),
#  (20, 'NC-17', 'Kowloon and New Kowloon', Decimal('13.98')),
#  (2, 'PG', 'Imus', Decimal('13.98')),
#  (6, 'NC-17', 'Santa F', Decimal('13.98')),
#  (21, 'NC-17', 'Tartu', Decimal('13.98')),
#  (30, 'G', 'Liaocheng', Decimal('13.98')),
#  (30, 'NC-17', 'Isesaki', Decimal('13.98')),
#  (9, 'R', 'Kowloon and New Kowloon', Decimal('13.98')),
#  (20, 'PG-13', 'Naju', Decimal('13.98')),
#  (9, 'PG-13', 'Baicheng', Decimal('13.98')),
#  (23, 'R', 'Joliet', Decimal('13.98')),
#  (1, 'PG-13', 'Haiphong', Decimal('13.98')),
#  (30, 'NC-17', 'Chatsworth', Decimal('13.98')),
#  (12, 'NC-17', 'Battambang', Decimal('13.98')),
#  (20, 'NC-17', 'Changzhou', Decimal('13.98')),
#  (19, 'PG', 'Sawhaj', Decimal('13.98')),
#  (11, 'PG-13', 'Boa Vista', Decimal('13.98')),
#  (29, 'PG-13', 'Qomsheh', Decimal('13.98')),
#  (17, 'PG-13', 'Tanza', Decimal('13.98')),
#  (8, 'R', 'El Fuerte', Decimal('13.98')),
#  (21, 'PG-13', 'Lublin', Decimal('13.98')),
#  (30, 'NC-17', 'Kermanshah', Decimal('13.98')),
#  (30, 'R', 'Sagamihara', Decimal('13.98')),
#  (29, 'PG-13', 'Jedda', Decimal('13.98')),
#  (27, 'G', 'Dhaka', Decimal('13.98')),
#  (22, 'NC-17', 'Halisahar', Decimal('13.98')),
#  (17, 'R', 'Cuman', Decimal('13.98')),
#  (28, 'R', 'Parbhani', Decimal('13.98')),
#  (21, 'PG-13', 'Apeldoorn', Decimal('13.98')),
#  (27, 'PG-13', 'Idfu', Decimal('13.98')),
#  (7, 'G', 'Soshanguve', Decimal('13.98')),
#  (29, 'PG-13', 'Maikop', Decimal('13.98')),
#  (23, 'PG', 'Donostia-San Sebastin', Decimal('13.98')),
#  (30, 'NC-17', 'Shanwei', Decimal('13.98')),
#  (21, 'NC-17', 'Shimoga', Decimal('13.98')),
#  (21, 'G', 'Olomouc', Decimal('13.98')),
#  (23, 'NC-17', 'Urawa', Decimal('13.98')),
#  (19, 'PG', 'Cam Ranh', Decimal('13.98')),
#  (20, 'G', 'Mannheim', Decimal('13.98')),
#  (9, 'G', 'Touliu', Decimal('13.98')),
#  (22, 'R', 'Nakhon Sawan', Decimal('13.98')),
#  (30, 'PG', 'Cabuyao', Decimal('13.98')),
#  (19, 'PG', 'Maracabo', Decimal('13.98')),
#  (20, 'PG', 'Huaian', Decimal('13.98')),
#  (27, 'NC-17', 'Iwaki', Decimal('13.98')),
#  (19, 'NC-17', 'Syrakusa', Decimal('13.98')),
#  (21, 'PG-13', 'Maracabo', Decimal('13.97')),
#  (30, 'PG-13', 'Boksburg', Decimal('13.97')),
#  (7, 'PG-13', 'Avellaneda', Decimal('13.97')),
#  (30, 'NC-17', 'Lengshuijiang', Decimal('13.97')),
#  (27, 'NC-17', 'Funafuti', Decimal('13.97')),
#  (18, 'PG', 'Lima', Decimal('13.97')),
#  (21, 'PG', 'Ogbomosho', Decimal('13.97')),
#  (29, 'G', 'Jhansi', Decimal('13.97')),
#  (18, 'R', 'Pyongyang', Decimal('13.97')),
#  (20, 'PG-13', 'Boa Vista', Decimal('13.96')),
#  (17, 'R', 'Balurghat', Decimal('12.98')),
#  (17, 'R', 'Rockford', Decimal('12.98')),
#  (21, 'PG-13', 'Etawah', Decimal('12.98')),
#  (28, 'G', 'Denizli', Decimal('12.98')),
#  (9, 'PG-13', 'Mysore', Decimal('12.98')),
#  (1, 'R', 'Pjatigorsk', Decimal('12.98')),
#  (17, 'R', 'Sterling Heights', Decimal('12.98')),
#  (19, 'PG', 'Lengshuijiang', Decimal('12.98')),
#  (2, 'NC-17', 'Atlixco', Decimal('12.98')),
#  (21, 'PG-13', 'Firozabad', Decimal('12.98')),
#  (30, 'PG', 'Lancaster', Decimal('12.98')),
#  (1, 'R', 'Kragujevac', Decimal('12.98')),
#  (17, 'PG-13', 's-Hertogenbosch', Decimal('12.98')),
#  (10, 'PG', 'Izumisano', Decimal('12.98')),
#  (30, 'NC-17', 'Buenaventura', Decimal('12.98')),
#  (20, 'R', 'Xinxiang', Decimal('12.98')),
#  (2, 'NC-17', 'Lapu-Lapu', Decimal('12.98')),
#  (22, 'G', 'Touliu', Decimal('12.98')),
#  (6, 'G', 'ostka', Decimal('12.98')),
#  (27, 'R', 'Merlo', Decimal('12.98')),
#  (18, 'NC-17', 'Araatuba', Decimal('12.98')),
#  (2, 'R', 'Huixquilucan', Decimal('12.98')),
#  (30, 'PG', 'Mannheim', Decimal('12.98')),
#  (10, 'G', 'Yinchuan', Decimal('12.98')),
#  (20, 'PG', 'Rizhao', Decimal('12.98')),
#  (11, 'R', 'Cape Coral', Decimal('12.98')),
#  (6, 'R', 'Apeldoorn', Decimal('12.98')),
#  (21, 'G', 'Grand Prairie', Decimal('12.98')),
#  (12, 'G', 'Chiayi', Decimal('12.98')),
#  (21, 'NC-17', 'Bergamo', Decimal('12.98')),
#  (27, 'G', 'Athenai', Decimal('12.98')),
#  (1, 'NC-17', 'Tel Aviv-Jaffa', Decimal('12.98')),
#  (19, 'PG-13', 'Pemalang', Decimal('12.98')),
#  (28, 'R', 'Citrus Heights', Decimal('12.98')),
#  (27, 'R', 'Hunuco', Decimal('12.98')),
#  (30, 'R', 'Benguela', Decimal('12.98')),
#  (18, 'PG-13', 'Yangor', Decimal('12.98')),
#  (17, 'PG', 'Davao', Decimal('12.98')),
#  (27, 'PG', 'Okinawa', Decimal('12.98')),
#  (7, 'PG', 'al-Qatif', Decimal('12.98')),
#  (20, 'G', 'Bhimavaram', Decimal('12.98')),
#  (5, 'PG-13', 'Nha Trang', Decimal('12.98')),
#  (30, 'R', 'Liaocheng', Decimal('12.98')),
#  (30, 'G', 'Simferopol', Decimal('12.98')),
#  (21, 'PG-13', 'Masqat', Decimal('12.98')),
#  (18, 'NC-17', 'Coacalco de Berriozbal', Decimal('12.98')),
#  (12, 'R', 'Sanya', Decimal('12.98')),
#  (17, 'PG-13', 'Usolje-Sibirskoje', Decimal('12.98')),
#  (18, 'PG-13', 'Udaipur', Decimal('12.98')),
#  (28, 'R', 'Newcastle', Decimal('12.98')),
#  (21, 'PG', 'Kuching', Decimal('12.98')),
#  (29, 'G', 'Junan', Decimal('12.98')),
#  (6, 'R', 'Erlangen', Decimal('12.98')),
#  (27, 'G', 'Cape Coral', Decimal('12.98')),
#  (27, 'PG', 'Fontana', Decimal('12.98')),
#  (23, 'R', 'Apeldoorn', Decimal('12.98')),
#  (28, 'G', 'Ourense (Orense)', Decimal('12.98')),
#  (1, 'G', 'Benin City', Decimal('12.98')),
#  (20, 'R', 'Araatuba', Decimal('12.98')),
#  (18, 'R', 'Kansas City', Decimal('12.98')),
#  (21, 'PG', 'Bijapur', Decimal('12.98')),
#  (7, 'PG-13', 'La Paz', Decimal('12.98')),
#  (28, 'NC-17', 'Dundee', Decimal('12.98')),
#  (22, 'NC-17', 'Ilorin', Decimal('12.98')),
#  (15, 'G', 'So Bernardo do Campo', Decimal('12.98')),
#  (29, 'PG-13', 'Aden', Decimal('12.98')),
#  (10, 'G', 'Zhezqazghan', Decimal('12.98')),
#  (18, 'PG-13', 'Kimberley', Decimal('12.98')),
#  (11, 'PG-13', 'Ife', Decimal('12.98')),
#  (17, 'NC-17', 'Arlington', Decimal('12.98')),
#  (18, 'PG-13', 'Ibirit', Decimal('12.98')),
#  (20, 'PG-13', 'Vilnius', Decimal('12.97')),
#  (26, 'PG-13', 'Iwaki', Decimal('12.97')),
#  (21, 'G', 'Tabriz', Decimal('12.97')),
#  (19, 'NC-17', 'Pyongyang', Decimal('12.97')),
#  (21, 'NC-17', 'Richmond Hill', Decimal('12.97')),
#  (27, 'PG-13', 'Quilmes', Decimal('12.97')),
#  (30, 'PG-13', 'Shaoguan', Decimal('12.97')),
#  (17, 'G', 'San Felipe del Progreso', Decimal('12.97')),
#  (30, 'PG', 'Isesaki', Decimal('12.97')),
#  (8, 'PG-13', 'Bucuresti', Decimal('12.97')),
#  (19, 'R', 'Juiz de Fora', Decimal('12.97')),
#  (30, 'G', 'Elista', Decimal('12.97')),
#  (22, 'PG-13', 'Ondo', Decimal('12.97')),
#  (18, 'NC-17', 'Najafabad', Decimal('12.97')),
#  (6, 'NC-17', 'Korla', Decimal('12.97')),
#  (30, 'PG', 'Salamanca', Decimal('12.96')),
#  (21, 'PG-13', 'Pemalang', Decimal('11.99')),
#  (25, 'PG-13', 'Mannheim', Decimal('11.99')),
#  (7, 'PG-13', 'Juiz de Fora', Decimal('11.99')),
#  (22, 'G', 'Usak', Decimal('11.99')),
#  (23, 'NC-17', 'Siegen', Decimal('11.99')),
#  (2, 'R', 'Naju', Decimal('11.99')),
#  (6, 'G', 'Szkesfehrvr', Decimal('11.99')),
#  (26, 'NC-17', 'Siliguri (Shiliguri)', Decimal('11.98')),
#  (18, 'G', 'Tangail', Decimal('11.98')),
#  (28, 'PG-13', 'Smolensk', Decimal('11.98')),
#  (20, 'NC-17', 'Imus', Decimal('11.98')),
#  (20, 'R', 'Jaffna', Decimal('11.98')),
#  (30, 'PG-13', 'Ivanovo', Decimal('11.98')),
#  (30, 'NC-17', 'Sungai Petani', Decimal('11.98')),
#  (30, 'G', 'Kursk', Decimal('11.98')),
#  (29, 'PG-13', 'Southport', Decimal('11.98')),
#  (11, 'NC-17', 'Johannesburg', Decimal('11.98')),
#  (30, 'R', 'Sumqayit', Decimal('11.98')),
#  (30, 'PG-13', 'Lhokseumawe', Decimal('11.98')),
#  (30, 'PG', 'Yamuna Nagar', Decimal('11.98')),
#  (19, 'PG', 'Bilbays', Decimal('11.98')),
#  (21, 'PG-13', 'Tychy', Decimal('11.98')),
#  (27, 'G', 'Juiz de Fora', Decimal('11.98')),
#  (31, 'R', 'Tabuk', Decimal('11.98')),
#  (29, 'PG-13', 'Uluberia', Decimal('11.98')),
#  (21, 'NC-17', 'Charlotte Amalie', Decimal('11.98')),
#  (28, 'PG-13', 'Elista', Decimal('11.98')),
#  (30, 'PG-13', 'Apeldoorn', Decimal('11.98')),
#  (22, 'G', 'Mysore', Decimal('11.98')),
#  (21, 'R', 'Mannheim', Decimal('11.98')),
#  (19, 'G', 'Ashqelon', Decimal('11.98')),
#  (22, 'R', 'Ikerre', Decimal('11.98')),
#  (21, 'R', 'Tieli', Decimal('11.98')),
#  (18, 'R', 'Brindisi', Decimal('11.98')),
#  (27, 'NC-17', 'Ambattur', Decimal('11.98')),
#  (22, 'G', 'Kisumu', Decimal('11.98')),
#  (10, 'NC-17', 'Lincoln', Decimal('11.98')),
#  (18, 'G', 'Monywa', Decimal('11.98')),
#  (10, 'PG-13', 'San Felipe del Progreso', Decimal('11.98')),
#  (1, 'PG-13', 'Iwakuni', Decimal('11.98')),
#  (18, 'NC-17', 'Urawa', Decimal('11.98')),
#  (19, 'R', 'Ife', Decimal('11.98')),
#  (2, 'G', 'Rustenburg', Decimal('11.98')),
#  (8, 'PG-13', 'Sivas', Decimal('11.98')),
#  (20, 'PG-13', 'Maring', Decimal('11.98')),
#  (27, 'PG-13', 'Mardan', Decimal('11.98')),
#  (28, 'R', 'Esfahan', Decimal('11.98')),
#  (18, 'NC-17', 'Santa F', Decimal('11.98')),
#  (17, 'PG-13', 'Zapopan', Decimal('11.98')),
#  (10, 'R', 'Czestochowa', Decimal('11.98')),
#  (2, 'PG-13', 'Antofagasta', Decimal('11.98')),
#  (23, 'PG', 'Tieli', Decimal('11.98')),
#  (17, 'G', 'Czestochowa', Decimal('11.98')),
#  (18, 'NC-17', 'Santo Andr', Decimal('11.98')),
#  (30, 'PG-13', 'La Romana', Decimal('11.98')),
#  (23, 'R', 'Quilmes', Decimal('11.98')),
#  (19, 'PG-13', 'Angra dos Reis', Decimal('11.98')),
#  (29, 'G', 'Koriyama', Decimal('11.98')),
#  (17, 'R', 'Monclova', Decimal('11.98')),
#  (9, 'PG-13', 'Kaliningrad', Decimal('11.98')),
#  (15, 'PG-13', 'Sumy', Decimal('11.98')),
#  (20, 'PG-13', 'Lancaster', Decimal('11.98')),
#  (23, 'G', 'Lancaster', Decimal('11.98')),
#  (30, 'R', 'Siegen', Decimal('11.98')),
#  (28, 'PG-13', 'Shubra al-Khayma', Decimal('11.98')),
#  (15, 'PG-13', 'Iwatsuki', Decimal('11.98')),
#  (1, 'PG-13', 'Miyakonojo', Decimal('11.98')),
#  (1, 'NC-17', 'Botshabelo', Decimal('11.98')),
#  (17, 'G', 'Kilis', Decimal('11.98')),
#  (23, 'G', 'Huixquilucan', Decimal('11.98')),
#  (20, 'G', 'Rancagua', Decimal('11.98')),
#  (28, 'PG', 'Naju', Decimal('11.98')),
#  (20, 'R', 'Nantou', Decimal('11.98')),
#  (27, 'R', 'Halle/Saale', Decimal('11.98')),
#  (12, 'PG-13', 'Portoviejo', Decimal('11.98')),
#  (14, 'PG-13', 'London', Decimal('11.98')),
#  (29, 'G', 'Rampur', Decimal('11.98')),
#  (21, 'PG-13', 'Bern', Decimal('11.98')),
#  (30, 'G', 'Zaria', Decimal('11.98')),
#  (20, 'NC-17', 'Nakhon Sawan', Decimal('11.98')),
#  (30, 'G', 'Jining', Decimal('11.98')),
#  (21, 'R', 'Firozabad', Decimal('11.98')),
#  (30, 'R', 'Valle de la Pascua', Decimal('11.98')),
#  (27, 'PG-13', 'Vijayawada', Decimal('11.98')),
#  (20, 'NC-17', 'Kabul', Decimal('11.98')),
#  (20, 'R', 'Osmaniye', Decimal('11.98')),
#  (30, 'PG', 'Mysore', Decimal('11.98')),
#  (23, 'PG', 'Pontianak', Decimal('11.98')),
#  (18, 'PG-13', 'Uluberia', Decimal('11.98')),
#  (1, 'R', 'El Fuerte', Decimal('11.98')),
#  (20, 'PG', 'Jalib al-Shuyukh', Decimal('11.98')),
#  (18, 'PG', 'Rampur', Decimal('11.98')),
#  (20, 'G', 'Qomsheh', Decimal('11.98')),
#  (15, 'PG', 'Madiun', Decimal('11.98')),
#  (30, 'PG', 'Po', Decimal('11.98')),
#  (29, 'NC-17', 'Sorocaba', Decimal('11.98')),
#  (27, 'NC-17', 'Jhansi', Decimal('11.98')),
#  (16, 'PG', 'Cape Coral', Decimal('11.98')),
#  (30, 'R', 'Ashdod', Decimal('11.97')),
#  (30, 'R', 'Udine', Decimal('11.97')),
#  (22, 'PG', 'Huaian', Decimal('11.97')),
#  (18, 'PG-13', 'Xiangfan', Decimal('11.97')),
#  (27, 'NC-17', 'Beira', Decimal('11.97')),
#  (1, 'NC-17', 'Bayugan', Decimal('11.97')),
#  (30, 'NC-17', 'Erlangen', Decimal('10.99')),
#  (2, 'NC-17', 'Cabuyao', Decimal('10.99')),
#  (1, 'PG', 'Smolensk', Decimal('10.99')),
#  (20, 'G', 'Ashgabat', Decimal('10.99')),
#  (23, 'G', 'Serpuhov', Decimal('10.99')),
#  (30, 'G', 'Gorontalo', Decimal('10.99')),
#  (18, 'PG', 'Hodeida', Decimal('10.99')),
#  (27, 'PG', 'Xintai', Decimal('10.99')),
#  (2, 'PG-13', 'Saint-Denis', Decimal('10.99')),
#  (9, 'G', 'Brockton', Decimal('10.99')),
#  (26, 'R', 'Toulon', Decimal('10.99')),
#  (18, 'R', 'Daugavpils', Decimal('10.99')),
#  (8, 'R', 'Ozamis', Decimal('10.99')),
#  (5, 'NC-17', 'Ourense (Orense)', Decimal('10.99')),
#  (22, 'PG-13', 'Ogbomosho', Decimal('10.99')),
#  (26, 'PG', 'Hodeida', Decimal('10.99')),
#  (16, 'PG', 'Battambang', Decimal('10.99')),
#  (18, 'R', 'Konotop', Decimal('10.99')),
#  (23, 'NC-17', 'Pavlodar', Decimal('10.99')),
#  (21, 'NC-17', 'Zhoushan', Decimal('10.99')),
#  (18, 'G', 'Stockport', Decimal('10.99')),
#  (12, 'R', 'Saint-Denis', Decimal('10.99')),
#  (28, 'PG-13', 'Stockport', Decimal('10.99')),
#  (22, 'PG-13', 'Iwakuni', Decimal('10.99')),
#  (19, 'PG-13', 'Blumenau', Decimal('10.99')),
#  (19, 'NC-17', 'Zhoushan', Decimal('10.99')),
#  (21, 'PG-13', 'Cavite', Decimal('10.99')),
#  (30, 'G', 'Zhezqazghan', Decimal('10.99')),
#  (10, 'R', 'Kakamigahara', Decimal('10.99')),
#  (21, 'R', 'Adoni', Decimal('10.99')),
#  (2, 'PG-13', 'Probolinggo', Decimal('10.99')),
#  (8, 'PG-13', 'Mwanza', Decimal('10.99')),
#  (30, 'PG-13', 'Baku', Decimal('10.99')),
#  (15, 'PG-13', 'Alessandria', Decimal('10.99')),
#  (20, 'PG', 'Pangkal Pinang', Decimal('10.99')),
#  (29, 'PG', 'Duisburg', Decimal('10.99')),
#  (20, 'PG-13', 'Plock', Decimal('10.99')),
#  (6, 'PG', 'Sumy', Decimal('10.99')),
#  (1, 'PG', 'Yamuna Nagar', Decimal('10.99')),
#  (6, 'NC-17', 'Ibirit', Decimal('10.99')),
#  (10, 'R', 'Guadalajara', Decimal('10.99')),
#  (25, 'R', 'Callao', Decimal('10.99')),
#  (9, 'NC-17', 'Santa Brbara dOeste', Decimal('10.99')),
#  (20, 'G', 'Suihua', Decimal('10.99')),
#  (21, 'NC-17', 'Rockford', Decimal('10.99')),
#  (30, 'G', 'Yantai', Decimal('10.99')),
#  (6, 'PG-13', 'Allende', Decimal('10.99')),
#  (17, 'PG', 'Datong', Decimal('10.99')),
#  (1, 'PG-13', 'Bhimavaram', Decimal('10.99')),
#  (30, 'G', 'Warren', Decimal('10.99')),
#  (22, 'PG-13', 'Rampur', Decimal('10.99')),
#  (17, 'R', 'Jinchang', Decimal('10.99')),
#  (10, 'G', 'Parbhani', Decimal('10.99')),
#  (22, 'NC-17', 'Kaliningrad', Decimal('10.99')),
#  (2, 'R', 'Bijapur', Decimal('10.99')),
#  (28, 'G', 'Songkhla', Decimal('10.99')),
#  (2, 'PG-13', 'Richmond Hill', Decimal('10.99')),
#  (7, 'PG', 'Santa F', Decimal('10.99')),
#  (29, 'NC-17', 'Garland', Decimal('10.99')),
#  (18, 'G', 'Sharja', Decimal('10.99')),
#  (28, 'G', 'Kermanshah', Decimal('10.99')),
#  (20, 'PG', 'Sincelejo', Decimal('10.99')),
#  (30, 'G', 'Mannheim', Decimal('10.99')),
#  (30, 'NC-17', 'Batna', Decimal('10.99')),
#  (19, 'NC-17', 'Clarksville', Decimal('10.99')),
#  (1, 'PG-13', 'Florencia', Decimal('10.99')),
#  (2, 'R', 'Rae Bareli', Decimal('10.99')),
#  (22, 'R', 'Omiya', Decimal('10.99')),
#  (29, 'NC-17', 'Uijongbu', Decimal('10.99')),
#  (30, 'PG-13', 'Jinzhou', Decimal('10.99')),
#  (21, 'R', 'San Lorenzo', Decimal('10.99')),
#  (23, 'NC-17', 'Antofagasta', Decimal('10.99')),
#  (9, 'PG', 'Shimonoseki', Decimal('10.99')),
#  (10, 'NC-17', 'Nha Trang', Decimal('10.99')),
#  (29, 'NC-17', 'San Felipe de Puerto Plata', Decimal('10.99')),
#  (26, 'PG-13', 'Angra dos Reis', Decimal('10.99')),
#  (27, 'PG-13', 'Purnea (Purnia)', Decimal('10.99')),
#  (1, 'G', 'Hunuco', Decimal('10.99')),
#  (20, 'G', 'Tangail', Decimal('10.99')),
#  (31, 'PG-13', 'Balaiha', Decimal('10.98')),
#  (18, 'G', 'Coacalco de Berriozbal', Decimal('10.98')),
#  (18, 'PG', 'Otsu', Decimal('10.98')),
#  (22, 'PG-13', 'Halifax', Decimal('10.98')),
#  (18, 'PG', 'Weifang', Decimal('10.98')),
#  (30, 'R', 'Aurora', Decimal('10.98')),
#  (17, 'NC-17', 'Ljubertsy', Decimal('10.98')),
#  (20, 'PG-13', 'Fukuyama', Decimal('10.98')),
#  (8, 'R', 'Citt del Vaticano', Decimal('10.98')),
#  (30, 'NC-17', 'Czestochowa', Decimal('10.98')),
#  (30, 'R', 'Dundee', Decimal('10.98')),
#  (27, 'NC-17', 'Hiroshima', Decimal('10.98')),
#  (21, 'PG-13', 'Mandaluyong', Decimal('10.98')),
#  (17, 'PG-13', 'Baicheng', Decimal('10.98')),
#  (18, 'R', 'Juiz de Fora', Decimal('10.98')),
#  (17, 'PG', 'Paarl', Decimal('10.98')),
#  (19, 'PG-13', 'Jalib al-Shuyukh', Decimal('10.98')),
#  (29, 'G', 'Kingstown', Decimal('10.98')),
#  (11, 'PG-13', 'Blumenau', Decimal('10.98')),
#  (27, 'PG-13', 'Udine', Decimal('10.98')),
#  (23, 'PG-13', 'guas Lindas de Gois', Decimal('10.98')),
#  (21, 'PG-13', 'Chisinau', Decimal('10.98')),
#  (17, 'NC-17', 'Ibirit', Decimal('10.98')),
#  (22, 'R', 'Lausanne', Decimal('10.98')),
#  (17, 'R', 'Sullana', Decimal('10.98')),
#  (21, 'PG', 'Antofagasta', Decimal('10.98')),
#  (18, 'G', 'Richmond Hill', Decimal('10.98')),
#  (9, 'PG', 'Wroclaw', Decimal('10.98')),
#  (19, 'R', 'Southampton', Decimal('10.98')),
#  (30, 'NC-17', 'Tonghae', Decimal('10.98')),
#  (20, 'PG', 'Oshawa', Decimal('10.98')),
#  (17, 'NC-17', 'Cayenne', Decimal('10.98')),
#  (8, 'G', 'Kurgan', Decimal('10.98')),
#  (29, 'NC-17', 'Yangor', Decimal('10.98')),
#  (1, 'R', 'Qinhuangdao', Decimal('10.98')),
#  (2, 'PG-13', 'Papeete', Decimal('10.98')),
#  (2, 'NC-17', 'Hsichuh', Decimal('10.98')),
#  (2, 'NC-17', 'Plock', Decimal('10.98')),
#  (19, 'PG-13', 'Tanza', Decimal('10.98')),
#  (30, 'G', 'Ibirit', Decimal('10.98')),
#  (18, 'G', 'Idfu', Decimal('10.98')),
#  (31, 'PG', 'Klerksdorp', Decimal('10.98')),
#  (20, 'PG-13', 'Tuguegarao', Decimal('10.98')),
#  (17, 'PG-13', 'Vancouver', Decimal('10.98')),
#  (30, 'PG-13', 'Usak', Decimal('10.98')),
#  (18, 'PG-13', 'al-Ayn', Decimal('10.98')),
#  (20, 'PG-13', 'Shanwei', Decimal('10.98')),
#  (29, 'PG', 'Bucuresti', Decimal('10.98')),
#  (8, 'PG-13', 'Jos Azueta', Decimal('10.98')),
#  (6, 'R', 'Valparai', Decimal('10.98')),
#  (18, 'PG-13', 'Amroha', Decimal('10.98')),
#  (30, 'G', 'Dallas', Decimal('10.98')),
#  (27, 'R', 'Chisinau', Decimal('10.98')),
#  (18, 'PG', 'Ljubertsy', Decimal('10.98')),
#  (6, 'NC-17', 'Brest', Decimal('10.98')),
#  (30, 'NC-17', 'Oshawa', Decimal('10.98')),
#  (20, 'R', 'Kamjanets-Podilskyi', Decimal('10.98')),
#  (30, 'PG-13', 'Memphis', Decimal('10.98')),
#  (16, 'PG', 'Shenzhen', Decimal('10.98')),
#  (30, 'G', 'Tongliao', Decimal('10.98')),
#  (27, 'PG', 'Richmond Hill', Decimal('10.98')),
#  (30, 'PG', 'Kimberley', Decimal('10.98')),
#  (20, 'PG', 'Jakarta', Decimal('10.98')),
#  (17, 'PG-13', 'Warren', Decimal('10.98')),
#  (21, 'PG', 'Witten', Decimal('10.98')),
#  (21, 'PG-13', 'Lubumbashi', Decimal('10.98')),
#  (30, 'PG-13', 'Jelets', Decimal('10.98')),
#  (19, 'PG-13', 'Saint-Denis', Decimal('10.98')),
#  (8, 'PG', 'Batman', Decimal('10.98')),
#  (12, 'PG', 'Sumqayit', Decimal('10.98')),
#  (2, 'PG-13', 'Salzburg', Decimal('10.98')),
#  (30, 'NC-17', 'Charlotte Amalie', Decimal('10.98')),
#  (28, 'R', 'Bhilwara', Decimal('10.98')),
#  (28, 'PG-13', 'Yantai', Decimal('10.98')),
#  (21, 'R', 'Santa Brbara dOeste', Decimal('10.98')),
#  (29, 'G', 'Jaffna', Decimal('10.98')),
#  (18, 'PG-13', 'Iwaki', Decimal('10.98')),
#  (27, 'PG-13', 'Uijongbu', Decimal('10.98')),
#  (30, 'NC-17', 'Halifax', Decimal('10.98')),
#  (11, 'PG-13', 'Najafabad', Decimal('10.98')),
#  (20, 'NC-17', 'Vaduz', Decimal('10.98')),
#  (19, 'NC-17', 'Omiya', Decimal('10.98')),
#  (28, 'PG', 'Probolinggo', Decimal('10.98')),
#  (19, 'NC-17', 'Iwaki', Decimal('10.98')),
#  (21, 'PG', 'Dayton', Decimal('10.98')),
#  (30, 'PG', 'Daxian', Decimal('10.98')),
#  (28, 'PG', 'Sirjan', Decimal('10.98')),
#  (9, 'R', 'Nantou', Decimal('10.98')),
#  (23, 'R', 'Naala-Porto', Decimal('10.98')),
#  (1, 'NC-17', 'Dadu', Decimal('10.98')),
#  (21, 'PG', 'Sanaa', Decimal('10.98')),
#  (2, 'NC-17', 'Okara', Decimal('10.98')),
#  (28, 'G', 'Rae Bareli', Decimal('10.98')),
#  (8, 'NC-17', 'Bucuresti', Decimal('10.98')),
#  (12, 'PG', 'Salinas', Decimal('10.98')),
#  (27, 'R', 'Santa Rosa', Decimal('10.98')),
#  (18, 'PG', 'Bhavnagar', Decimal('10.98')),
#  (16, 'PG-13', 'Botosani', Decimal('10.98')),
#  (16, 'PG', 'Halisahar', Decimal('10.98')),
#  (18, 'PG', 'Chandrapur', Decimal('10.98')),
#  (17, 'PG-13', 'Southend-on-Sea', Decimal('10.98')),
#  (20, 'PG-13', 'Bhopal', Decimal('10.98')),
#  (17, 'R', 'Acua', Decimal('10.98')),
#  (18, 'R', 'Shahr-e Kord', Decimal('10.98')),
#  (27, 'R', 'Yuncheng', Decimal('10.98')),
#  (19, 'NC-17', 'Cavite', Decimal('10.98')),
#  (6, 'G', 'Papeete', Decimal('10.98')),
#  (29, 'G', 'Battambang', Decimal('10.98')),
#  (7, 'PG', 'Szkesfehrvr', Decimal('10.98')),
#  (29, 'NC-17', 'Juazeiro do Norte', Decimal('10.98')),
#  (30, 'NC-17', 'ostka', Decimal('10.98')),
#  (28, 'PG', 'Xiangfan', Decimal('10.98')),
#  (30, 'PG-13', 'Qinhuangdao', Decimal('10.98')),
#  (19, 'NC-17', 'Hidalgo', Decimal('10.98')),
#  (27, 'NC-17', 'Bhilwara', Decimal('10.98')),
#  (8, 'PG', 'Shivapuri', Decimal('10.98')),
#  (29, 'PG', 'Haining', Decimal('10.98')),
#  (28, 'R', 'Qomsheh', Decimal('10.98')),
#  (30, 'PG-13', 'Sousse', Decimal('10.98')),
#  (30, 'PG', 'Kamakura', Decimal('10.97')),
#  (30, 'NC-17', 'Kolpino', Decimal('10.97')),
#  (21, 'PG', 'Malm', Decimal('10.97')),
#  (27, 'PG-13', 'Uluberia', Decimal('10.97')),
#  (30, 'PG-13', 'Kirovo-Tepetsk', Decimal('10.97')),
#  (29, 'PG', 'Jinchang', Decimal('10.97')),
#  (30, 'NC-17', 'Okinawa', Decimal('10.97')),
#  (1, 'G', 'Bratislava', Decimal('10.97')),
#  (17, 'PG-13', 'Sanaa', Decimal('10.97')),
#  (21, 'PG-13', 'Peoria', Decimal('10.97')),
#  (18, 'NC-17', 'Ziguinchor', Decimal('10.97')),
#  (17, 'G', 'Ahmadnagar', Decimal('10.97')),
#  (23, 'PG-13', 'Tanshui', Decimal('10.97')),
#  (22, 'NC-17', 'Laohekou', Decimal('10.97')),
#  (30, 'PG', 'Saint-Denis', Decimal('10.97')),
#  (17, 'G', 'Mandaluyong', Decimal('9.99')),
#  (10, 'G', 'Otsu', Decimal('9.99')),
#  (17, 'G', 'Tabora', Decimal('9.99')),
#  (28, 'PG-13', 'Loja', Decimal('9.99')),
#  (27, 'G', 'Braslia', Decimal('9.99')),
#  (11, 'NC-17', 'Matamoros', Decimal('9.99')),
#  (2, 'R', 'Escobar', Decimal('9.99')),
#  (15, 'PG', 'Sasebo', Decimal('9.99')),
#  (27, 'G', 'Alvorada', Decimal('9.99')),
#  (19, 'PG-13', 'Kowloon and New Kowloon', Decimal('9.99')),
#  (23, 'PG', 'Ourense (Orense)', Decimal('9.99')),
#  (19, 'NC-17', 'Qinhuangdao', Decimal('9.99')),
#  (21, 'PG', 'Ipoh', Decimal('9.99')),
#  (29, 'PG', 'Meixian', Decimal('9.99')),
#  (27, 'NC-17', 'Citrus Heights', Decimal('9.99')),
#  (30, 'G', 'Liepaja', Decimal('9.99')),
#  (29, 'G', 'Ipoh', Decimal('9.99')),
#  (12, 'NC-17', 'Tieli', Decimal('9.99')),
#  (12, 'NC-17', 'Binzhou', Decimal('9.99')),
#  (19, 'PG-13', 'Bellevue', Decimal('9.99')),
#  (30, 'PG-13', 'Huejutla de Reyes', Decimal('9.99')),
#  (15, 'G', 'Najafabad', Decimal('9.99')),
#  (18, 'R', 'Southampton', Decimal('9.99')),
#  (27, 'G', 'Otsu', Decimal('9.99')),
#  (8, 'NC-17', 'Mahajanga', Decimal('9.99')),
#  (11, 'NC-17', 'Clarksville', Decimal('9.99')),
#  (7, 'R', 'Benguela', Decimal('9.99')),
#  (19, 'R', 'Uruapan', Decimal('9.99')),
#  (12, 'PG-13', 'Pingxiang', Decimal('9.99')),
#  (28, 'NC-17', 'Pontianak', Decimal('9.99')),
#  (6, 'G', 'Southampton', Decimal('9.99')),
#  (19, 'NC-17', 'Sunnyvale', Decimal('9.99')),
#  (21, 'PG-13', 'Osmaniye', Decimal('9.99')),
#  (8, 'PG', 'Santa Rosa', Decimal('9.99')),
#  (18, 'R', 'Vancouver', Decimal('9.99')),
#  (20, 'PG', 'Bucuresti', Decimal('9.99')),
#  (28, 'NC-17', 'Dhule (Dhulia)', Decimal('9.99')),
#  (29, 'PG-13', 'Bergamo', Decimal('9.99')),
#  (7, 'PG-13', 'Tianjin', Decimal('9.99')),
#  (7, 'PG', 'Effon-Alaiye', Decimal('9.99')),
#  (30, 'PG', 'Uluberia', Decimal('9.99')),
#  (17, 'PG-13', 'London', Decimal('9.99')),
#  (5, 'G', 'Fontana', Decimal('9.99')),
#  (19, 'PG-13', 'Cuauhtmoc', Decimal('9.99')),
#  (20, 'PG', 'Probolinggo', Decimal('9.99')),
#  (30, 'PG', 'Santiago de Compostela', Decimal('9.99')),
#  (15, 'PG', 'Jedda', Decimal('9.99')),
#  (16, 'PG-13', 'Ourense (Orense)', Decimal('9.99')),
#  (18, 'PG', 'Cuauhtmoc', Decimal('9.99')),
#  (23, 'PG-13', 'Kursk', Decimal('9.99')),
#  (1, 'PG', 'Oshawa', Decimal('9.99')),
#  (12, 'NC-17', 'Wroclaw', Decimal('9.99')),
#  (28, 'R', 'Sawhaj', Decimal('9.99')),
#  (24, 'PG', 'San Felipe del Progreso', Decimal('9.99')),
#  (27, 'PG-13', 'Abha', Decimal('9.99')),
#  (28, 'NC-17', 'Gaziantep', Decimal('9.99')),
#  (29, 'NC-17', 'Qomsheh', Decimal('9.99')),
#  (28, 'PG', 'Hiroshima', Decimal('9.99')),
#  (19, 'NC-17', 'Gaziantep', Decimal('9.99')),
#  (20, 'PG-13', 'Santa Brbara dOeste', Decimal('9.99')),
#  (22, 'PG', 'Pangkal Pinang', Decimal('9.99')),
#  (6, 'NC-17', 'Nuuk', Decimal('9.99')),
#  (7, 'G', 'Shahr-e Kord', Decimal('9.99')),
#  (26, 'NC-17', 'Bydgoszcz', Decimal('9.99')),
#  (23, 'R', 'Shanwei', Decimal('9.99')),
#  (28, 'PG-13', 'Bradford', Decimal('9.99')),
#  (18, 'R', 'Cabuyao', Decimal('9.99')),
#  (16, 'PG', 'Mukateve', Decimal('9.99')),
#  (8, 'NC-17', 'Peoria', Decimal('9.99')),
#  (10, 'PG-13', 'Rustenburg', Decimal('9.99')),
#  (11, 'R', 'Juazeiro do Norte', Decimal('9.99')),
#  (30, 'PG-13', 'Uruapan', Decimal('9.99')),
#  (29, 'PG', 'Memphis', Decimal('9.99')),
#  (18, 'NC-17', 'Jhansi', Decimal('9.99')),
#  (17, 'G', 'Nantou', Decimal('9.99')),
#  (8, 'PG-13', 'Mosul', Decimal('9.99')),
#  (21, 'R', 'Kanazawa', Decimal('9.99')),
#  (25, 'G', 'Vaduz', Decimal('9.99')),
#  (19, 'PG', 'Laohekou', Decimal('9.99')),
#  (29, 'PG-13', 'Kolpino', Decimal('9.99')),
#  (8, 'R', 'Hsichuh', Decimal('9.99')),
#  (20, 'PG-13', 'Sincelejo', Decimal('9.99')),
#  (27, 'NC-17', 'Kamakura', Decimal('9.99')),
#  (10, 'PG', 'Talavera', Decimal('9.99')),
#  (30, 'G', 'Botosani', Decimal('9.99')),
#  (23, 'PG', 'Vaduz', Decimal('9.99')),
#  (6, 'PG-13', 'Wroclaw', Decimal('9.99')),
#  (6, 'PG', 'Kolpino', Decimal('9.99')),
#  (21, 'R', 'Hidalgo', Decimal('9.99')),
#  (12, 'R', 'Jakarta', Decimal('9.99')),
#  (20, 'NC-17', 'Bag', Decimal('9.99')),
#  (30, 'G', 'Bat Yam', Decimal('9.99')),
#  (25, 'PG', 'Kimberley', Decimal('9.99')),
#  (29, 'NC-17', 'Nanyang', Decimal('9.99')),
#  (20, 'PG', 'Nuuk', Decimal('9.99')),
#  (7, 'G', 'Salinas', Decimal('9.99')),
#  (17, 'R', 'Citt del Vaticano', Decimal('9.99')),
#  (26, 'NC-17', 'Plock', Decimal('9.99')),
#  (23, 'NC-17', 'Cape Coral', Decimal('9.99')),
#  (30, 'R', 'Funafuti', Decimal('9.99')),
#  (19, 'NC-17', 'Pontianak', Decimal('9.99')),
#  (27, 'PG-13', 'Kuching', Decimal('9.99')),
#  (27, 'PG', 'Munger (Monghyr)', Decimal('9.99')),
#  (18, 'PG', 'Tambaram', Decimal('9.99')),
#  (9, 'G', 'ostka', Decimal('9.99')),
#  (2, 'G', 'Valle de Santiago', Decimal('9.99')),
#  (6, 'G', 'Jinzhou', Decimal('9.99')),
#  (22, 'G', 'Robamba', Decimal('9.99')),
#  (12, 'PG', 'Molodetno', Decimal('9.99')),
#  (2, 'PG', 'Beni-Mellal', Decimal('9.99')),
#  (30, 'R', 'Udaipur', Decimal('9.99')),
#  (11, 'PG-13', 'Almirante Brown', Decimal('9.99')),
#  (23, 'NC-17', 'Emeishan', Decimal('9.99')),
#  (11, 'G', 'Atlixco', Decimal('9.99')),
#  (27, 'R', 'Xiangtan', Decimal('9.99')),
#  (12, 'PG', 'Pangkal Pinang', Decimal('9.99')),
#  (23, 'R', 'Bhilwara', Decimal('9.99')),
#  (17, 'G', 'Basel', Decimal('9.99')),
#  (30, 'NC-17', 'Mosul', Decimal('9.99')),
#  (30, 'PG', 'Sagamihara', Decimal('9.99')),
#  (8, 'PG-13', 'Kamarhati', Decimal('9.99')),
#  (19, 'R', 'Brescia', Decimal('9.99')),
#  (22, 'PG-13', 'Hanoi', Decimal('9.99')),
#  (10, 'PG-13', 'Santiago de los Caballeros', Decimal('9.99')),
#  (28, 'PG', 'Saint-Denis', Decimal('9.99')),
#  (30, 'R', 'York', Decimal('9.99')),
#  (16, 'NC-17', 'Qalyub', Decimal('9.99')),
#  (28, 'PG', 'Kamyin', Decimal('9.99')),
#  (21, 'PG-13', 'Bijapur', Decimal('9.99')),
#  (20, 'G', 'Blumenau', Decimal('9.99')),
#  (1, 'NC-17', 'Owo', Decimal('9.99')),
#  (20, 'NC-17', 'al-Manama', Decimal('9.99')),
#  (18, 'PG', 'Gijn', Decimal('9.99')),
#  (29, 'R', 'Sawhaj', Decimal('9.99')),
#  (8, 'NC-17', 'Pereira', Decimal('9.99')),
#  (21, 'PG', 'Qomsheh', Decimal('9.99')),
#  (2, 'PG-13', 'al-Hawiya', Decimal('9.99')),
#  (7, 'PG', 'Yerevan', Decimal('9.99')),
#  (9, 'PG', 'Jhansi', Decimal('9.99')),
#  (22, 'PG', 'Bergamo', Decimal('9.99')),
#  (9, 'G', 'Lungtan', Decimal('9.99')),
#  (19, 'NC-17', 'Sal', Decimal('9.99')),
#  (29, 'R', 'Yangor', Decimal('9.99')),
#  (1, 'R', 'Vila Velha', Decimal('9.99')),
#  (18, 'PG-13', 'Nador', Decimal('9.99')),
#  (20, 'PG', 'Witten', Decimal('9.99')),
#  (28, 'G', 'Simferopol', Decimal('9.99')),
#  (17, 'NC-17', 'Lapu-Lapu', Decimal('9.99')),
#  (19, 'R', 'Dos Quebradas', Decimal('9.99')),
#  (16, 'PG', 'Niznekamsk', Decimal('9.99')),
#  (19, 'PG-13', 'Siliguri (Shiliguri)', Decimal('9.99')),
#  (2, 'G', 'Hamilton', Decimal('9.99')),
#  (9, 'R', 'Tokat', Decimal('9.99')),
#  (28, 'G', 'Zanzibar', Decimal('9.99')),
#  (21, 'PG-13', 'Kanchrapara', Decimal('9.99')),
#  (2, 'G', 'Pjatigorsk', Decimal('9.99')),
#  (19, 'G', 'Vancouver', Decimal('9.99')),
#  (6, 'PG-13', 'Uttarpara-Kotrung', Decimal('9.99')),
#  (28, 'PG-13', 'Vancouver', Decimal('9.99')),
#  (2, 'NC-17', 'Quilmes', Decimal('9.99')),
#  (11, 'G', 'Donostia-San Sebastin', Decimal('9.99')),
#  (29, 'G', 'Ede', Decimal('9.99')),
#  (8, 'PG', 'Songkhla', Decimal('9.99')),
#  (21, 'PG-13', 'Dos Quebradas', Decimal('9.99')),
#  (28, 'G', 'Rustenburg', Decimal('9.99')),
#  (2, 'PG-13', 'Po', Decimal('9.99')),
#  (16, 'R', 'Donostia-San Sebastin', Decimal('9.99')),
#  (21, 'NC-17', 'Arak', Decimal('9.99')),
#  (18, 'G', 'Mukateve', Decimal('9.99')),
#  (29, 'NC-17', 'Addis Abeba', Decimal('9.99')),
#  (17, 'PG-13', 'Erlangen', Decimal('9.99')),
#  (19, 'G', 'Pudukkottai', Decimal('9.99')),
#  (26, 'G', 'Baybay', Decimal('9.99')),
#  (20, 'PG', 'Juiz de Fora', Decimal('9.99')),
#  (20, 'PG-13', 'Nyeri', Decimal('9.99')),
#  (8, 'PG', 'Lipetsk', Decimal('9.99')),
#  (28, 'R', 'Ilorin', Decimal('9.99')),
#  (29, 'PG-13', 'Joliet', Decimal('9.99')),
#  (27, 'PG', 'Arecibo', Decimal('9.99')),
#  (17, 'G', 'Mwene-Ditu', Decimal('9.99')),
#  (20, 'PG-13', 'Leshan', Decimal('9.99')),
#  (6, 'PG-13', 'Kalisz', Decimal('9.99')),
#  (29, 'R', 'Manchester', Decimal('9.99')),
#  (9, 'NC-17', 'Tabriz', Decimal('9.99')),
#  (12, 'NC-17', 'Asuncin', Decimal('9.99')),
#  (2, 'R', 'Okayama', Decimal('9.99')),
#  (30, 'PG', 'Ponce', Decimal('9.99')),
#  (21, 'NC-17', 'Karnal', Decimal('9.99')),
#  (26, 'R', 'Antofagasta', Decimal('9.99')),
#  (20, 'R', 'Tangail', Decimal('9.99')),
#  (8, 'NC-17', 'Dos Quebradas', Decimal('9.99')),
#  (12, 'R', 'Denizli', Decimal('9.99')),
#  (30, 'G', 'Baiyin', Decimal('9.99')),
#  (19, 'R', 'Ashdod', Decimal('9.99')),
#  (22, 'PG', 'Zhoushan', Decimal('9.99')),
#  (6, 'R', 'Caracas', Decimal('9.99')),
#  (10, 'PG', 'Olomouc', Decimal('9.99')),
#  (6, 'NC-17', 'Joliet', Decimal('9.99')),
#  (17, 'G', 'Mit Ghamr', Decimal('9.98')),
#  (2, 'G', 'Banjul', Decimal('9.98')),
#  (2, 'PG', 'Kaduna', Decimal('9.98')),
#  (1, 'PG', 'NDjamna', Decimal('9.98')),
#  (30, 'G', 'Balikesir', Decimal('9.98')),
#  (6, 'NC-17', 'Aden', Decimal('9.98')),
#  (27, 'G', 'Charlotte Amalie', Decimal('9.98')),
#  (27, 'R', 'Batman', Decimal('9.98')),
#  (20, 'PG', 'Laiwu', Decimal('9.98')),
#  (10, 'G', 'La Romana', Decimal('9.98')),
#  (30, 'NC-17', 'Balikesir', Decimal('9.98')),
#  (27, 'G', 'Tabora', Decimal('9.98')),
#  (30, 'G', 'Izumisano', Decimal('9.98')),
#  (17, 'R', 'Kurashiki', Decimal('9.98')),
#  (23, 'R', 'Chandrapur', Decimal('9.98')),
#  (8, 'G', 'Aden', Decimal('9.98')),
#  (17, 'PG-13', 'Cuauhtmoc', Decimal('9.98')),
#  (19, 'NC-17', 'Bandar Seri Begawan', Decimal('9.98')),
#  (20, 'PG-13', 'Chapra', Decimal('9.98')),
#  (23, 'PG', 'Yaound', Decimal('9.98')),
#  (28, 'PG-13', 'Miyakonojo', Decimal('9.98')),
#  (11, 'PG', 'Okara', Decimal('9.98')),
#  (20, 'NC-17', 'Talavera', Decimal('9.98')),
#  (20, 'G', 'Palghat (Palakkad)', Decimal('9.98')),
#  (15, 'PG-13', 'Qinhuangdao', Decimal('9.98')),
#  (9, 'PG', 'Chandrapur', Decimal('9.98')),
#  (17, 'PG', 'Jalib al-Shuyukh', Decimal('9.98')),
#  (21, 'PG', 'Shubra al-Khayma', Decimal('9.98')),
#  (1, 'PG', 'Changhwa', Decimal('9.98')),
#  (19, 'G', 'Mukateve', Decimal('9.98')),
#  (17, 'NC-17', 'Compton', Decimal('9.98')),
#  (30, 'PG-13', 'Jurez', Decimal('9.98')),
#  (17, 'G', 'al-Manama', Decimal('9.98')),
#  (19, 'NC-17', 'Lhokseumawe', Decimal('9.98')),
#  (11, 'NC-17', 'Xiangfan', Decimal('9.98')),
#  (18, 'PG', 'Eskisehir', Decimal('9.98')),
#  (20, 'NC-17', 'Santiago de los Caballeros', Decimal('9.98')),
#  (18, 'PG-13', 'Sanaa', Decimal('9.98')),
#  (20, 'PG', 'Batna', Decimal('9.98')),
#  (9, 'R', 'Tandil', Decimal('9.98')),
#  (30, 'PG-13', 'Sambhal', Decimal('9.98')),
#  (30, 'PG', 'Liepaja', Decimal('9.98')),
#  (20, 'G', 'Najafabad', Decimal('9.98')),
#  (1, 'NC-17', 'Tartu', Decimal('9.98')),
#  (28, 'PG-13', 'Kuwana', Decimal('9.98')),
#  (9, 'R', 'Tianjin', Decimal('9.98')),
#  (19, 'PG-13', 'Liepaja', Decimal('9.98')),
#  (1, 'NC-17', 'Witten', Decimal('9.98')),
#  (20, 'PG', 'Berhampore (Baharampur)', Decimal('9.98')),
#  (28, 'R', 'Saint-Denis', Decimal('9.98')),
#  (21, 'PG', 'Southport', Decimal('9.98')),
#  (17, 'NC-17', 'Kansas City', Decimal('9.98')),
#  (23, 'PG-13', 'Graz', Decimal('9.98')),
#  (9, 'PG', 'Probolinggo', Decimal('9.98')),
#  (21, 'R', 'Sorocaba', Decimal('9.98')),
#  (22, 'PG-13', 'Omdurman', Decimal('9.98')),
#  (7, 'NC-17', 'Bandar Seri Begawan', Decimal('9.98')),
#  (30, 'PG', 'Tieli', Decimal('9.98')),
#  (8, 'PG-13', 'Najafabad', Decimal('9.98')),
#  (23, 'PG', 'Nabereznyje Telny', Decimal('9.98')),
#  (21, 'R', 'Ciudad del Este', Decimal('9.98')),
#  (21, 'R', 'Tanshui', Decimal('9.98')),
#  (21, 'R', 'Zhoushan', Decimal('9.98')),
#  (18, 'NC-17', 'Lipetsk', Decimal('9.98')),
#  (18, 'NC-17', 'Addis Abeba', Decimal('9.98')),
#  (21, 'NC-17', 'Southend-on-Sea', Decimal('9.98')),
#  (18, 'PG', 'Cuman', Decimal('9.98')),
#  (30, 'NC-17', 'Southampton', Decimal('9.98')),
#  (19, 'R', 'Korolev', Decimal('9.98')),
#  (21, 'PG-13', 'Jakarta', Decimal('9.98')),
#  (28, 'PG-13', 'Ourense (Orense)', Decimal('9.98')),
#  (1, 'NC-17', 'Tanshui', Decimal('9.98')),
#  (22, 'PG', 'So Bernardo do Campo', Decimal('9.98')),
#  (30, 'NC-17', 'Toulon', Decimal('9.98')),
#  (22, 'G', 'Amersfoort', Decimal('9.98')),
#  (12, 'NC-17', 'El Monte', Decimal('9.98')),
#  (6, 'NC-17', 'Guadalajara', Decimal('9.98')),
#  (12, 'NC-17', 'Tegal', Decimal('9.98')),
#  (28, 'PG-13', 'Yerevan', Decimal('9.98')),
#  (27, 'PG', 'Tychy', Decimal('9.98')),
#  (18, 'R', 'Uttarpara-Kotrung', Decimal('9.98')),
#  (20, 'G', 'Parbhani', Decimal('9.98')),
#  (20, 'R', 'Liaocheng', Decimal('9.98')),
#  (12, 'PG-13', 'Ikerre', Decimal('9.98')),
#  (11, 'PG', 'Sanaa', Decimal('9.98')),
#  (30, 'PG', 'Ahmadnagar', Decimal('9.98')),
#  (27, 'PG-13', 'Lipetsk', Decimal('9.98')),
#  (18, 'NC-17', 'Zaoyang', Decimal('9.98')),
#  (27, 'R', 'Ozamis', Decimal('9.98')),
#  (30, 'R', 'Beira', Decimal('9.98')),
#  (23, 'G', 'San Juan Bautista Tuxtepec', Decimal('9.98')),
#  (30, 'R', 'Baiyin', Decimal('9.98')),
#  (30, 'R', 'Jinchang', Decimal('9.98')),
#  (28, 'PG', 'Daugavpils', Decimal('9.98')),
#  (21, 'PG', 'Pontianak', Decimal('9.98')),
#  (8, 'PG-13', 'Torren', Decimal('9.98')),
#  (11, 'PG-13', 'Buenaventura', Decimal('9.98')),
#  (11, 'G', 'Tegal', Decimal('9.98')),
#  (30, 'PG', 'Karnal', Decimal('9.98')),
#  (6, 'R', 'Novi Sad', Decimal('9.98')),
#  (18, 'R', 'Papeete', Decimal('9.98')),
#  (28, 'PG-13', 'Enshi', Decimal('9.98')),
#  (17, 'NC-17', 'Celaya', Decimal('9.98')),
#  (10, 'NC-17', 'Jastrzebie-Zdrj', Decimal('9.98')),
#  (30, 'R', 'Bhusawal', Decimal('9.98')),
#  (1, 'R', 'Ourense (Orense)', Decimal('9.98')),
#  (15, 'PG', 'Pontianak', Decimal('9.98')),
#  (29, 'G', 'Stockport', Decimal('9.98')),
#  (28, 'PG', 'Tsuyama', Decimal('9.98')),
#  (10, 'NC-17', 'Bislig', Decimal('9.98')),
#  (21, 'G', 'Fontana', Decimal('9.98')),
#  (19, 'PG', 'Memphis', Decimal('9.98')),
#  (17, 'PG-13', 'Patiala', Decimal('9.98')),
#  (30, 'R', 'Jastrzebie-Zdrj', Decimal('9.98')),
#  (14, 'R', 'Jaipur', Decimal('9.98')),
#  (19, 'PG-13', 'Guadalajara', Decimal('9.98')),
#  (19, 'G', 'Halle/Saale', Decimal('9.98')),
#  (31, 'NC-17', 'Ktahya', Decimal('9.98')),
#  (18, 'G', 'Jaffna', Decimal('9.98')),
#  (10, 'R', 'Fuyu', Decimal('9.98')),
#  (19, 'PG-13', 'Hiroshima', Decimal('9.98')),
#  (9, 'PG', 'Warren', Decimal('9.98')),
#  (30, 'G', 'Dhule (Dhulia)', Decimal('9.98')),
#  (1, 'G', 'Hohhot', Decimal('9.98')),
#  (28, 'R', 'Grand Prairie', Decimal('9.98')),
#  (23, 'PG-13', 'Kakamigahara', Decimal('9.98')),
#  (1, 'PG-13', 'Ife', Decimal('9.98')),
#  (19, 'PG', 'Okara', Decimal('9.98')),
#  (30, 'NC-17', 'Ashqelon', Decimal('9.98')),
#  (29, 'PG', 'Tonghae', Decimal('9.98')),
#  (27, 'PG-13', 'Skikda', Decimal('9.98')),
#  (30, 'PG-13', 'Omdurman', Decimal('9.98')),
#  (30, 'NC-17', 'Bandar Seri Begawan', Decimal('9.98')),
#  (29, 'PG', 'Tokat', Decimal('9.98')),
#  (30, 'R', 'Yamuna Nagar', Decimal('9.98')),
#  (8, 'NC-17', 'NDjamna', Decimal('9.98')),
#  (28, 'PG-13', 'Tafuna', Decimal('9.98')),
#  (29, 'PG', 'Benguela', Decimal('9.98')),
#  (27, 'NC-17', 'Kitwe', Decimal('9.98')),
#  (30, 'PG', 'Baku', Decimal('9.98')),
#  (30, 'G', 'Rampur', Decimal('9.98')),
#  (9, 'NC-17', 'Vinh', Decimal('9.98')),
#  (20, 'PG', 'Salzburg', Decimal('9.98')),
#  (20, 'NC-17', 'Surakarta', Decimal('9.98')),
#  (2, 'NC-17', 'Qalyub', Decimal('9.98')),
#  (19, 'PG-13', 'Donostia-San Sebastin', Decimal('9.98')),
#  (17, 'PG-13', 'Coquimbo', Decimal('9.98')),
#  (30, 'NC-17', 'South Hill', Decimal('9.98')),
#  (28, 'PG', 'Aurora', Decimal('9.98')),
#  (30, 'PG-13', 'Emeishan', Decimal('9.98')),
#  (17, 'PG', 'Tabriz', Decimal('9.98')),
#  (16, 'PG', 'Ede', Decimal('9.98')),
#  (20, 'R', 'Garland', Decimal('9.98')),
#  (9, 'PG-13', 'Richmond Hill', Decimal('9.98')),
#  (30, 'G', 'Goinia', Decimal('9.98')),
#  (18, 'PG', 'Emmen', Decimal('9.98')),
#  (6, 'G', 'Hodeida', Decimal('9.98')),
#  (30, 'PG', 'Xintai', Decimal('9.98')),
#  (23, 'G', 'Maikop', Decimal('9.98')),
#  (27, 'R', 'Nakhon Sawan', Decimal('9.98')),
#  (29, 'G', 'Batna', Decimal('9.98')),
#  (29, 'PG-13', 'Probolinggo', Decimal('9.98')),
#  (27, 'PG-13', 'Basel', Decimal('9.98')),
#  (17, 'NC-17', 'Tanauan', Decimal('9.98')),
#  (12, 'PG-13', 'Nyeri', Decimal('9.98')),
#  (30, 'PG', 'Banjul', Decimal('9.98')),
#  (21, 'R', 'Hoshiarpur', Decimal('9.98')),
#  (1, 'PG', 'Meixian', Decimal('9.98')),
#  (28, 'R', 'Athenai', Decimal('9.98')),
#  (21, 'PG-13', 'Erlangen', Decimal('9.98')),
#  (28, 'PG-13', 'Lungtan', Decimal('9.98')),
#  (31, 'NC-17', 'Omdurman', Decimal('9.98')),
#  (9, 'PG', 'Tuguegarao', Decimal('9.98')),
#  (18, 'NC-17', 'Palghat (Palakkad)', Decimal('9.98')),
#  (9, 'R', 'El Monte', Decimal('9.98')),
#  (20, 'PG-13', 'Lapu-Lapu', Decimal('9.97')),
#  (30, 'PG', 'Higashiosaka', Decimal('9.97')),
#  (27, 'PG', 'Kamarhati', Decimal('9.97')),
#  (20, 'PG', 'Callao', Decimal('9.97')),
#  (18, 'PG', 'Kurashiki', Decimal('9.97')),
#  (20, 'NC-17', 'Mwanza', Decimal('9.97')),
#  (28, 'NC-17', 'Tel Aviv-Jaffa', Decimal('9.97')),
#  (17, 'NC-17', 'Lungtan', Decimal('9.97')),
#  (9, 'G', 'Brindisi', Decimal('9.97')),
#  (1, 'R', 'Inegl', Decimal('9.97')),
#  (30, 'G', 'Changzhou', Decimal('9.97')),
#  (1, 'NC-17', 'Liaocheng', Decimal('9.96')),
#  (11, 'R', 'Nantou', Decimal('8.99')),
#  (30, 'PG', 'Baicheng', Decimal('8.99')),
#  (1, 'G', 'Salamanca', Decimal('8.99')),
#  (2, 'PG-13', 'Iligan', Decimal('8.99')),
#  (17, 'G', 'York', Decimal('8.99')),
#  (21, 'NC-17', 'Sucre', Decimal('8.99')),
#  (20, 'R', 'Mexicali', Decimal('8.99')),
#  (27, 'PG-13', 'Usolje-Sibirskoje', Decimal('8.99')),
#  (6, 'R', 'Jelets', Decimal('8.99')),
#  (30, 'NC-17', 'Etawah', Decimal('8.99')),
#  (9, 'PG-13', 'Jaroslavl', Decimal('8.99')),
#  ...]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>G</td>
#         <td>San Bernardino</td>
#         <td>24.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>NC-17</td>
#         <td>Apeldoorn</td>
#         <td>23.95</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>NC-17</td>
#         <td>Belm</td>
#         <td>22.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>R</td>
#         <td>Mwanza</td>
#         <td>21.97</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Slicing
#
# Slicing is the reduction of the dimensionality of a cube by 1 e.g. 3 dimensions to 2, fixing one of the dimensions to a single value. In the example above, we have a 3-dimensional cube on day, rating, and country.
#
# TODO: Write a query that reduces the dimensionality of the above example by limiting the results to only include movies with a `rating` of "PG-13". Again, sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT
    dt.day,
    dm.rating,
    dc.city,
    sum(sales_amount) as revenue
FROM factSales fs 
JOIN dimDate dt ON (dt.date_key = fs.date_key)
JOIN dimCustomer dc ON (dc.customer_key = fs.customer_key)
JOIN dimMovie dm ON (dm.movie_key = fs.movie_key)
WHERE dm.rating = 'PG-13'
GROUP BY dt.day, dm.rating, dc.city
ORDER BY 4 DESC
LIMIT 20
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 20 rows affected.
# CPU times: user 5.47 ms, sys: 133 µs, total: 5.61 ms
# Wall time: 12 ms
# [(30, 'PG-13', 'Zanzibar', Decimal('21.97')),
#  (28, 'PG-13', 'Dhaka', Decimal('19.97')),
#  (30, 'PG-13', 'Osmaniye', Decimal('18.97')),
#  (29, 'PG-13', 'Shimoga', Decimal('18.97')),
#  (21, 'PG-13', 'Asuncin', Decimal('18.95')),
#  (21, 'PG-13', 'Parbhani', Decimal('17.98')),
#  (20, 'PG-13', 'Baha Blanca', Decimal('17.98')),
#  (30, 'PG-13', 'Nagareyama', Decimal('17.98')),
#  (30, 'PG-13', 'Tanauan', Decimal('17.96')),
#  (17, 'PG-13', 'Ikerre', Decimal('17.95')),
#  (30, 'PG-13', 'Zhoushan', Decimal('16.98')),
#  (30, 'PG-13', 'Yerevan', Decimal('16.97')),
#  (30, 'PG-13', 'Newcastle', Decimal('16.97')),
#  (20, 'PG-13', 'Santa Rosa', Decimal('15.98')),
#  (17, 'PG-13', 'Yantai', Decimal('15.98')),
#  (30, 'PG-13', 'Santa Rosa', Decimal('15.98')),
#  (8, 'PG-13', 'Pontianak', Decimal('15.98')),
#  (30, 'PG-13', 'Toulouse', Decimal('15.97')),
#  (23, 'PG-13', 'Tiefa', Decimal('15.97')),
#  (1, 'PG-13', 'Moscow', Decimal('15.97'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>PG-13</td>
#         <td>Dhaka</td>
#         <td>19.97</td>
#     </tr>
#     <tr>
#         <td>29</td>
#         <td>PG-13</td>
#         <td>Shimoga</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Osmaniye</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>PG-13</td>
#         <td>Asuncin</td>
#         <td>18.95</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Dicing
# Dicing is creating a subcube with the same dimensionality but fewer values for  two or more dimensions.
#
# TODO: Write a query to create a subcube of the initial cube that includes moves with:
# * ratings of PG or PG-13
# * in the city of Bellevue or Lancaster
# * day equal to 1, 15, or 30
#
# The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT
    dt.day,
    dm.rating,
    dc.city,
    sum(fs.sales_amount) as revenue 
FROM factSales fs
JOIN dimDate dt ON (dt.date_key = fs.date_key)
JOIN dimCustomer dc ON (dc.customer_key = fs.customer_key)
JOIN dimMovie dm ON (dm.movie_key = fs.movie_key)
WHERE 
    dm.rating IN ('PG-13', 'PG')
    AND dc.city IN ('Bellevue', 'Lancaster')
    AND dt.day IN ('1','15','30')
GROUP BY dt.day, dm.rating, dc.city
ORDER BY 4 DESC
LIMIT 20
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 6 rows affected.
# CPU times: user 4.14 ms, sys: 794 µs, total: 4.94 ms
# Wall time: 6.49 ms
# [(30, 'PG', 'Lancaster', Decimal('12.98')),
#  (1, 'PG-13', 'Lancaster', Decimal('5.99')),
#  (30, 'PG-13', 'Bellevue', Decimal('3.99')),
#  (30, 'PG-13', 'Lancaster', Decimal('2.99')),
#  (15, 'PG-13', 'Bellevue', Decimal('1.98')),
#  (1, 'PG', 'Bellevue', Decimal('0.99'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG</td>
#         <td>Lancaster</td>
#         <td>12.98</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>5.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>3.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>2.99</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>1.98</td>
#     </tr>
# </tbody></table></div>
